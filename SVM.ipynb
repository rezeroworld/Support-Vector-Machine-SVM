# %% [markdown]
# # Goal
# The goal of this notebook is to test the SVM algorithm with one vs all approach on a reduced version of CIFAR-100 dataset, the algorithm is implemented in solution.py file

# %% [markdown]
# ## Prepare the data

# %%
# import the libraries
import numpy as np
import solution

# %%
# Load the data 
X_train, y_train, X_test, y_test = solution.load_data()
# Out:
# Loading data...
# data loaded successfully

# %% [markdown]
# ## Test the model on different values of C
# C has a lot of names, it is wildely called the tolerance term and represents the tolerance to classification error in case the data are not linearly separable, it also acts as a regularization term. We try different values for C ($0.1$, $1$ and $30$) and see the result on the training loss, testing loss, training accuracy and testing accuracy.

# %%
# Test the model
solution.train_and_test(X_train, y_train, X_test, y_test)
# Out:
# Fitting the model...
# Iteration 0 | Train loss 31.5299 | Train acc 0.3036 | Test loss 31.5435 | Test acc 0.2960
# Iteration 1 | Train loss 31.2678 | Train acc 0.3211 | Test loss 31.2888 | Test acc 0.3125
# Iteration 2 | Train loss 31.0802 | Train acc 0.3311 | Test loss 31.1067 | Test acc 0.3222
# Iteration 3 | Train loss 30.9344 | Train acc 0.3366 | Test loss 30.9657 | Test acc 0.3280
# Iteration 4 | Train loss 30.8165 | Train acc 0.3432 | Test loss 30.8522 | Test acc 0.3347
# Iteration 5 | Train loss 30.7180 | Train acc 0.3485 | Test loss 30.7578 | Test acc 0.3410
# Iteration 6 | Train loss 30.6332 | Train acc 0.3514 | Test loss 30.6768 | Test acc 0.3448
# Iteration 7 | Train loss 30.5584 | Train acc 0.3549 | Test loss 30.6056 | Test acc 0.3488
# Iteration 8 | Train loss 30.4908 | Train acc 0.3595 | Test loss 30.5414 | Test acc 0.3510
# Iteration 9 | Train loss 30.4286 | Train acc 0.3619 | Test loss 30.4824 | Test acc 0.3525
# ...

# %% [markdown]
# It seems the model is not performing great even after $50$ epochs of training but what we get from the plots is that a high $C$ value has a bad impact on accuracy. We can either try some preprocessing method like we did with Parzen methods or try a more advanced algorithm like neural nets.
